# %%
import pandas as pd
import numpy as np

# %%
path = "Data/FR_youtube_trending_data.csv"
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (86191, 16)

# %%
video = df.loc[df.video_id == '0jYCePaBl2A']
video
# Out:
#           video_id                                          title  \
# 59795  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 59995  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 60200  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 60405  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 60622  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 60828  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 61046  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 61273  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 61484  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 61712  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 61927  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 62136  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# 62358  0jYCePaBl2A  JuL  - Alors la zone \\ Clip Officiel \\ 2021
# ...

# %%
subset = df[['video_id','trending_date','view_count','likes','dislikes','comment_count']]
subset.head()
# Out:
#       video_id         trending_date  view_count   likes  dislikes  \
# 0  7rlwxSPUcQk  2020-08-12T00:00:00Z     1943013  165557      4198
# 1  AcBd_RH9JSw  2020-08-12T00:00:00Z     1823553  346839      2767
# 2  JVm8P6kKgD0  2020-08-12T00:00:00Z      196340   22362       187
# 3  JfgeD7xWy-w  2020-08-12T00:00:00Z      311609   29561       418
# 4  P3IkBxra3a8  2020-08-12T00:00:00Z      100691   10471        90
#
#    comment_count
# 0          15777
# 1           8030
# 2           1148
# 3           3213
# 4            384

# %%
subset['views_evo'] = np.nan
subset['likes_evo'] = np.nan
subset['dislikes_evo'] = np.nan
subset['comments_evo'] = np.nan
subset['trending_j'] = ''
# Out:
# /tmp/ipykernel_9233/3328785232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['views_evo'] = np.nan
# /tmp/ipykernel_9233/3328785232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['likes_evo'] = np.nan
# /tmp/ipykernel_9233/3328785232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
video = subset.loc[subset.video_id == '_IBQr33bWlY']

# %%
video
# Out:
#          video_id         trending_date  view_count  likes  dislikes  \
# 3006  _IBQr33bWlY  2020-08-27T00:00:00Z       76013   2136        55
# 3537  _IBQr33bWlY  2020-08-29T00:00:00Z      142382   3072        89
# 3773  _IBQr33bWlY  2020-08-30T00:00:00Z      155750   3247        96
#
#       comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# 3006             49        NaN        NaN           NaN           NaN
# 3537             90        NaN        NaN           NaN           NaN
# 3773            101        NaN        NaN           NaN           NaN
#
#      trending_j
# 3006
# 3537
# 3773

# %%
video
# Out:
#          video_id         trending_date  view_count  likes  dislikes  \
# 3006  _IBQr33bWlY  2020-08-27T00:00:00Z       76013   2136        55
# 3537  _IBQr33bWlY  2020-08-29T00:00:00Z      142382   3072        89
# 3773  _IBQr33bWlY  2020-08-30T00:00:00Z      155750   3247        96
#
#       comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# 3006             49        NaN        NaN           NaN           NaN
# 3537             90        NaN        NaN           NaN           NaN
# 3773            101        NaN        NaN           NaN           NaN
#
#      trending_j
# 3006
# 3537
# 3773

# %%
view_list = []
for ind in video.index:
    view_number = video['view_count'][ind]
    view_list.append(view_number)

# %%
list_vid = subset['video_id'].to_list()
list_vid = list(dict.fromkeys(list_vid))

# %%
list_vid
# Out:
# ['7rlwxSPUcQk',
#  'AcBd_RH9JSw',
#  'JVm8P6kKgD0',
#  'JfgeD7xWy-w',
#  'P3IkBxra3a8',
#  'AwdfloSJrtA',
#  'J9iT2z0-lTc',
#  'zatMgEXo4Ko',
#  '56HGTFZabxA',
#  'n0rGxQw5Ics',
#  'DTs12U36x54',
#  'jbGRowa5tIk',
#  'emuvKXZo-f4',
#  'Fi4CK7VnjUo',
#  'M9Pmf9AB4Mo',
#  'F5O74jJCUw0',
#  'NSzzW7OL-NU',
#  '1iquDlgygCU',
#  'bVg6k_uuz_M',
#  'NOXbqMN821s',
#  'kwxv3bypATY',
#  'vmIYhLuNqdA',
#  'SExxIJcLk-Y',
#  'CflyQsnucgA',
#  'P_5B4TkOdXk',
#  '5LnJOpGisto',
#  'QMyp5kxcDuo',
#  'uhAc2XnipcI',
#  'zrsBjYukE8s',
#  'H_iQthDvovo',
#  'HCTs89A8ljg',
#  'xJd6Utbbijc',
#  '2avPJ9TZNmU',
#  '-_5LIRgmWkc',
#  'LzpF2EGapDs',
#  'X_FE1rhzCNc',
#  'Ru4eE0AIqN8',
#  'JHrSYhtN7k8',
#  'vriK-mBCLEw',
#  '1BCrynpl6fs',
#  '2MfvRmLxNK8',
#  'ReL3kZQvKFQ',
#  'C3K68fdLKj8',
#  'ls4KyjhQPqk',
#  'RLpghfZB7_g',
#  'kA_k9n9JKxY',
#  'zeKWOYSmN2I',
#  'ku3jSdw3sn8',
#  'h4T2X2x7RFU',
#  'xTpr7piQu2M',
#  'IoLTYXwSC0g',
#  'EYdFLiXarHU',
#  'U3AJtpW5rYY',
#  'X2vVO-5d_hM',
#  'SMWURiJ-nHU',
# ...

# %%
def getVidFromId(list_vid):
    for vid in list_vid:
        video = subset.loc[subset.video_id == vid]
        print(video)

# %%
subset = subset[subset.groupby('video_id').video_id.transform(len)>2]

# %%
subset
# Out:
#           video_id         trending_date  view_count   likes  dislikes  \
# 0      7rlwxSPUcQk  2020-08-12T00:00:00Z     1943013  165557      4198
# 1      AcBd_RH9JSw  2020-08-12T00:00:00Z     1823553  346839      2767
# 2      JVm8P6kKgD0  2020-08-12T00:00:00Z      196340   22362       187
# 3      JfgeD7xWy-w  2020-08-12T00:00:00Z      311609   29561       418
# 4      P3IkBxra3a8  2020-08-12T00:00:00Z      100691   10471        90
# ...            ...                   ...         ...     ...       ...
# 86186  kZlLTnE1y1Q  2021-10-10T00:00:00Z     7265873  462661      9020
# 86187  RLCwj-fNcU4  2021-10-10T00:00:00Z      573059   28247       345
# 86188  U_Q2QX9r9ZQ  2021-10-10T00:00:00Z      160135   13746       331
# 86189  txZXxVxik0A  2021-10-10T00:00:00Z      199896   19213       304
# 86190  wXXrva-0-t4  2021-10-10T00:00:00Z       67631    5733        41
#
#        comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# ...

# %%
subset['video_id'].value_counts()
# Out:
# n3UBSa7-H0U    18
# q8Um2sEz8sw    16
# dpPTTmcCpdg    15
# wIp3AMRAB5E    15
# 0jYCePaBl2A    15
#                ..
# 9ckE6kU4aY4     3
# aFkjSHgNG1s     3
# jmfyr9J0n9A     3
# FI_gUZXrsZk     3
# DIF4M5_c6N8     3
# Name: video_id, Length: 16642, dtype: int64

# %%
video2 = subset.loc[subset.video_id == 'AOwyd6l8KvM']
video2
# Out:
#           video_id         trending_date  view_count   likes  dislikes  \
# 76631  AOwyd6l8KvM  2021-08-24T00:00:00Z      518823  121053        97
# 76861  AOwyd6l8KvM  2021-08-25T00:00:00Z      727751  139909       134
# 77079  AOwyd6l8KvM  2021-08-26T00:00:00Z      903840  151645       153
# 77317  AOwyd6l8KvM  2021-08-27T00:00:00Z     1073045  162128       170
# 77563  AOwyd6l8KvM  2021-08-28T00:00:00Z     1220998  170164       180
# 77780  AOwyd6l8KvM  2021-08-29T00:00:00Z     1350081  176597       190
#
#        comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# 76631              0        NaN        NaN           NaN           NaN
# 76861              1        NaN        NaN           NaN           NaN
# 77079              1        NaN        NaN           NaN           NaN
# 77317              1        NaN        NaN           NaN           NaN
# 77563              1        NaN        NaN           NaN           NaN
# ...

# %%
video_id = "AOwyd6l8KvM"

def make_ratios(video_id):
    subdf = subset.loc[subset.video_id == video_id]
    subdf['views_evo'] = round(subdf['view_count'].pct_change(1),3)
    subdf['likes_evo'] = round(subdf['likes'].pct_change(1),3)
    subdf['dislikes_evo'] = round(subdf['dislikes'].pct_change(1),3)
    subdf['comments_evo'] = round(subdf['comment_count'].pct_change(1),3)

    subdf = subdf.replace([np.inf, -np.inf], 0)

    subdf['trending_j'] = 1
    last = subdf.iloc[-1:]
    last['trending_j'] = 0
    subdf.update(last)
    subset.update(subdf)

    return subdf

# %%
subdf = make_ratios(video_id)
subdf
# Out:
# /tmp/ipykernel_9233/548365499.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['views_evo'] = round(subdf['view_count'].pct_change(1),3)
# /tmp/ipykernel_9233/548365499.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['likes_evo'] = round(subdf['likes'].pct_change(1),3)
# /tmp/ipykernel_9233/548365499.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for vid in list_vid:
    make_ratios(vid)
# Out:
# /tmp/ipykernel_9233/548365499.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['views_evo'] = round(subdf['view_count'].pct_change(1),3)
# /tmp/ipykernel_9233/548365499.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['likes_evo'] = round(subdf['likes'].pct_change(1),3)
# /tmp/ipykernel_9233/548365499.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
subset
# Out:
#           video_id         trending_date  view_count     likes  dislikes  \
# 0      7rlwxSPUcQk  2020-08-12T00:00:00Z   1943013.0  165557.0    4198.0
# 1      AcBd_RH9JSw  2020-08-12T00:00:00Z   1823553.0  346839.0    2767.0
# 2      JVm8P6kKgD0  2020-08-12T00:00:00Z    196340.0   22362.0     187.0
# 3      JfgeD7xWy-w  2020-08-12T00:00:00Z    311609.0   29561.0     418.0
# 4      P3IkBxra3a8  2020-08-12T00:00:00Z    100691.0   10471.0      90.0
# ...            ...                   ...         ...       ...       ...
# 86186  kZlLTnE1y1Q  2021-10-10T00:00:00Z   7265873.0  462661.0    9020.0
# 86187  RLCwj-fNcU4  2021-10-10T00:00:00Z    573059.0   28247.0     345.0
# 86188  U_Q2QX9r9ZQ  2021-10-10T00:00:00Z    160135.0   13746.0     331.0
# 86189  txZXxVxik0A  2021-10-10T00:00:00Z    199896.0   19213.0     304.0
# 86190  wXXrva-0-t4  2021-10-10T00:00:00Z     67631.0    5733.0      41.0
#
#        comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# ...

# %%
subset = subset.replace([np.inf, -np.inf], 0)
subset = subset.replace(np.nan,1.0)

# %%
ex = subset.loc[subset.video_id == 'AOwyd6l8KvM']
ex
# Out:
#           video_id         trending_date  view_count     likes  dislikes  \
# 76631  AOwyd6l8KvM  2021-08-24T00:00:00Z    518823.0  121053.0      97.0
# 76861  AOwyd6l8KvM  2021-08-25T00:00:00Z    727751.0  139909.0     134.0
# 77079  AOwyd6l8KvM  2021-08-26T00:00:00Z    903840.0  151645.0     153.0
# 77317  AOwyd6l8KvM  2021-08-27T00:00:00Z   1073045.0  162128.0     170.0
# 77563  AOwyd6l8KvM  2021-08-28T00:00:00Z   1220998.0  170164.0     180.0
# 77780  AOwyd6l8KvM  2021-08-29T00:00:00Z   1350081.0  176597.0     190.0
#
#        comment_count  views_evo  likes_evo  dislikes_evo  comments_evo  \
# 76631            0.0      1.000      1.000         1.000           1.0
# 76861            1.0      0.403      0.156         0.381           0.0
# 77079            1.0      0.242      0.084         0.142           0.0
# 77317            1.0      0.187      0.069         0.111           0.0
# 77563            1.0      0.138      0.050         0.059           0.0
# ...

# %%
pred_df = subset.drop('trending_date',axis=1)

# %%
pred_df
# Out:
#           video_id  view_count     likes  dislikes  comment_count  views_evo  \
# 0      7rlwxSPUcQk   1943013.0  165557.0    4198.0        15777.0      1.000
# 1      AcBd_RH9JSw   1823553.0  346839.0    2767.0         8030.0      1.000
# 2      JVm8P6kKgD0    196340.0   22362.0     187.0         1148.0      1.000
# 3      JfgeD7xWy-w    311609.0   29561.0     418.0         3213.0      1.000
# 4      P3IkBxra3a8    100691.0   10471.0      90.0          384.0      1.000
# ...            ...         ...       ...       ...            ...        ...
# 86186  kZlLTnE1y1Q   7265873.0  462661.0    9020.0        17020.0      0.102
# 86187  RLCwj-fNcU4    573059.0   28247.0     345.0          261.0      0.019
# 86188  U_Q2QX9r9ZQ    160135.0   13746.0     331.0          450.0      0.055
# 86189  txZXxVxik0A    199896.0   19213.0     304.0          964.0      0.056
# 86190  wXXrva-0-t4     67631.0    5733.0      41.0          203.0      0.262
#
# ...

# %%
pred_df2 = pred_df.loc[pred_df.trending_j == 1.0]
pred_df3 = pred_df.loc[pred_df.trending_j == 0.0]
_sample1 = pred_df2.sample(n=16642,random_state=1)
frame = [pred_df3,_sample1]
equal_df = pd.concat(frame)
equal_df
# Out:
#           video_id  view_count    likes  dislikes  comment_count  views_evo  \
# 549    ReL3kZQvKFQ     94007.0   6323.0     143.0         1399.0      0.105
# 551    xTpr7piQu2M   1420164.0  68284.0    7891.0         5733.0      0.058
# 553    zeKWOYSmN2I    727673.0  73540.0     628.0         3591.0      0.034
# 554    xJd6Utbbijc    183667.0  16444.0     586.0          520.0      0.034
# 559    NxcY-xrFv0s     37261.0   2859.0      56.0          342.0      0.153
# ...            ...         ...      ...       ...            ...        ...
# 64356  sCsiBjHmhcs   4555993.0  66320.0    2706.0         8005.0      0.029
# 41321  B6oV7Es-PpM   1155532.0  89158.0     685.0         5185.0      0.043
# 41903  ZsqZSQHuBUc    128633.0   1913.0      71.0          302.0      0.053
# 15697  g6nKoq9pixY    186134.0   2953.0     164.0          400.0      0.064
# 79201  6w5ZXCEf3D0    486166.0  44986.0     441.0          725.0      0.297
#
#        likes_evo  dislikes_evo  comments_evo  trending_j
# ...

# %%
df_natanael = equal_df[['views_evo','likes_evo','dislikes_evo','comments_evo']]
df_natanael_y = equal_df['trending_j']

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
X_trainn, X_testn, y_trainn, y_testn = train_test_split(df_natanael, df_natanael_y, test_size = 0.2,random_state=1)

# %%
X_trainn
# Out:
#        views_evo  likes_evo  dislikes_evo  comments_evo
# 52005      0.175      0.113         0.206         0.070
# 44167      0.003      1.000         1.000         0.000
# 55118      0.165      0.067         0.058         0.031
# 48388      0.076      0.032         0.051         0.021
# 80694      0.077      0.055         0.072         0.057
# ...          ...        ...           ...           ...
# 37741      0.067      0.026         0.045         0.023
# 72918      0.060      0.034         0.049         0.009
# 24766      0.076      0.052         0.072         0.046
# 62978      0.035      0.031         0.008         0.008
# 73021      1.000      1.000         1.000         1.000
#
# [26627 rows x 4 columns]

# %%
import pandas as pd
timeData = pd.read_csv("Data/data_ratios.csv",index_col="trending_date")

# %%
timeData = timeData.drop("Unnamed: 0",axis=1)

# %%
pred_df2 = timeData.loc[timeData.trending_j == 1.0]
pred_df3 = timeData.loc[timeData.trending_j == 0.0]
_sample1 = pred_df2.sample(n=16642,random_state=1)
frame = [pred_df3,_sample1]
timeData = pd.concat(frame)
timeData
# Out:
#                   video_id  view_count    likes  dislikes  comment_count  \
# trending_date
# 2020-08-14     ReL3kZQvKFQ     94007.0   6323.0     143.0         1399.0
# 2020-08-14     xTpr7piQu2M   1420164.0  68284.0    7891.0         5733.0
# 2020-08-14     zeKWOYSmN2I    727673.0  73540.0     628.0         3591.0
# 2020-08-14     xJd6Utbbijc    183667.0  16444.0     586.0          520.0
# 2020-08-14     NxcY-xrFv0s     37261.0   2859.0      56.0          342.0
# ...                    ...         ...      ...       ...            ...
# 2021-06-22     sCsiBjHmhcs   4555993.0  66320.0    2706.0         8005.0
# 2021-03-10     B6oV7Es-PpM   1155532.0  89158.0     685.0         5185.0
# 2021-03-13     ZsqZSQHuBUc    128633.0   1913.0      71.0          302.0
# 2020-10-30     g6nKoq9pixY    186134.0   2953.0     164.0          400.0
# 2021-09-06     6w5ZXCEf3D0    486166.0  44986.0     441.0          725.0
#
#                views_evo  likes_evo  dislikes_evo  comments_evo  trending_j
# ...

# %%
timeData
# Out:
#                   video_id  view_count    likes  dislikes  comment_count  \
# trending_date
# 2020-08-14     ReL3kZQvKFQ     94007.0   6323.0     143.0         1399.0
# 2020-08-14     xTpr7piQu2M   1420164.0  68284.0    7891.0         5733.0
# 2020-08-14     zeKWOYSmN2I    727673.0  73540.0     628.0         3591.0
# 2020-08-14     xJd6Utbbijc    183667.0  16444.0     586.0          520.0
# 2020-08-14     NxcY-xrFv0s     37261.0   2859.0      56.0          342.0
# ...                    ...         ...      ...       ...            ...
# 2021-06-22     sCsiBjHmhcs   4555993.0  66320.0    2706.0         8005.0
# 2021-03-10     B6oV7Es-PpM   1155532.0  89158.0     685.0         5185.0
# 2021-03-13     ZsqZSQHuBUc    128633.0   1913.0      71.0          302.0
# 2020-10-30     g6nKoq9pixY    186134.0   2953.0     164.0          400.0
# 2021-09-06     6w5ZXCEf3D0    486166.0  44986.0     441.0          725.0
#
#                views_evo  likes_evo  dislikes_evo  comments_evo  trending_j
# ...

# %%
X = timeData[['views_evo','likes_evo','dislikes_evo','comments_evo']]
y = timeData['trending_j']

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit()
for train_index, test_index in tscv.split(timeData):
          print("TRAIN:", train_index, "TEST:", test_index)
          X_train, X_test = X.iloc[train_index], X.iloc[test_index]
          y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# Out:
# TRAIN: [   0    1    2 ... 5546 5547 5548] TEST: [ 5549  5550  5551 ... 11093 11094 11095]
# TRAIN: [    0     1     2 ... 11093 11094 11095] TEST: [11096 11097 11098 ... 16640 16641 16642]
# TRAIN: [    0     1     2 ... 16640 16641 16642] TEST: [16643 16644 16645 ... 22187 22188 22189]
# TRAIN: [    0     1     2 ... 22187 22188 22189] TEST: [22190 22191 22192 ... 27734 27735 27736]
# TRAIN: [    0     1     2 ... 27734 27735 27736] TEST: [27737 27738 27739 ... 33281 33282 33283]

# %% [markdown]
# KNN part

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=33)
knn.fit(X_trainn,y_trainn)
# Out:
# KNeighborsClassifier(n_neighbors=33)

# %%
y_pred = knn.predict(X_testn)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score

print("knn accuracy : ",accuracy_score(y_testn, y_pred))
print(confusion_matrix(y_testn, y_pred))
print(classification_report(y_testn, y_pred))
# Out:
# knn accuracy :  0.7570977917981072
# [[2848  557]
#  [1060 2192]]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.84      0.78      3405
#          1.0       0.80      0.67      0.73      3252
#
#     accuracy                           0.76      6657
#    macro avg       0.76      0.76      0.75      6657
# weighted avg       0.76      0.76      0.76      6657

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

plt.figure()
plt.title('Matrice')
confusion_matrix = pd.crosstab(y_testn, y_pred, rownames=['True labels'], colnames=['Predicted labels'])
sns.heatmap(confusion_matrix, annot=True,xticklabels=['FAUX', 'VRAI'],yticklabels=['FAUX', 'VRAI'])
plt.show()

# %%
import matplotlib.pyplot as plt


error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_trainn,y_trainn)
 pred_i = knn.predict(X_testn)
 error_rate.append(np.mean(pred_i != y_testn))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.24140003004356317 at K = 33

# %%
import matplotlib.pyplot as plt
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(X_trainn,y_trainn)
    yhat = neigh.predict(X_testn)
    acc.append(metrics.accuracy_score(y_testn, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# Maximum accuracy:- 0.7585999699564369 at K = 33

# %% [markdown]
# TSNE

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, random_state=42)
X_reduced_tsne = tsne.fit_transform(df_natanael)
# Out:
# /usr/local/python/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/python/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.figure(figsize=(14,4))
plt.scatter(X_reduced_tsne[:,0],X_reduced_tsne[:,1],c=df_natanael_y.values)
plt.show()

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=112)

clf.fit(X_trainn,y_trainn)

y_pred = clf.predict(X_testn)

# %%
print("Accuracy:",metrics.accuracy_score(y_testn,y_pred))
# Out:
# Accuracy: 0.7407240498723149

# %%
fn=data.feature_names
cn=data.target_names
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=800)
tree.plot_tree(rf.estimators_[0],
               feature_names = fn, 
               class_names=cn,
               filled = True)

# %%
import matplotlib.pyplot as plt
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,200):
    neigh = RandomForestClassifier(n_estimators= i).fit(X_trainn,y_trainn)
    yhat = neigh.predict(X_testn)
    acc.append(metrics.accuracy_score(y_testn, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,200),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# Maximum accuracy:- 0.7428270992939763 at K = 112

# %%
from sklearn.model_selection import GridSearchCV

rfc = RandomForestClassifier(random_state=42)

param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_trainn, y_trainn)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
rfc1=RandomForestClassifier(random_state=42, max_features='auto', n_estimators= 200, max_depth=4, criterion='gini')

# %%
rfc1.fit(X_trainn, y_trainn)
pred=rfc1.predict(X_testn)

print("Accuracy for Random Forest on CV data: ",accuracy_score(y_testn,pred))
# Out:
# Accuracy for Random Forest on CV data:  0.7637073756947574

# %% [markdown]
# on veut recuperer les elements ou le modele a fait une erreur

# %%
X_testn["trend"] = y_testn
X_testn["prediction"] = pred
errorDetection = X_testn.copy()

# %%
errorDetection["video_id"] = equal_df["video_id"]

# %%
ErrorDf = pd.DataFrame(columns=['views_evo', 'likes_evo', 'dislikes_evo', 'comments_evo', 'prediction',
       'trend'])

# %%
for i in range(len(errorDetection)):
    line = errorDetection.iloc[i]
    if line["prediction"] != line["trend"]:
        ErrorDf = ErrorDf.append(line)
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...

# %%
ErrorDf["prediction"].value_counts()
# Out:
# 0.0    1133
# 1.0     441
# Name: prediction, dtype: int64

# %%
FalseNeg = ErrorDf.loc[ErrorDf.prediction == 1.0]
FalseNeg
# Out:
#        views_evo  likes_evo  dislikes_evo  comments_evo  prediction  trend  \
# 41166      0.234      0.073         0.197         0.059         1.0    0.0
# 67573      0.164      0.083         0.058         0.022         1.0    0.0
# 78361      0.226      0.070         0.257         0.108         1.0    0.0
# 4356       0.148      0.089         0.072         0.074         1.0    0.0
# 42186      0.241      0.114         0.212         0.049         1.0    0.0
# ...          ...        ...           ...           ...         ...    ...
# 15314      0.156      0.085         0.162         0.060         1.0    0.0
# 18576      0.371      0.349         0.230         0.224         1.0    0.0
# 8578       0.181      0.086         0.182         0.060         1.0    0.0
# 34382      0.211      0.090         0.095         0.072         1.0    0.0
# 84167      0.113      0.088         0.113         0.122         1.0    0.0
#
#           video_id
# 41166  wMu1pu3f6DQ
# 67573  FyZMFt0Mgj4
# ...

# %%
print("average evolution of comments :",FalseNeg["comments_evo"].mean())
print("average evolution of views :",FalseNeg["views_evo"].mean())
print("average evolution of likes :",FalseNeg["likes_evo"].mean())
print("average evolution of dislikes :",FalseNeg["dislikes_evo"].mean())
# Out:
# average evolution of comments : 0.10804761904761905
# average evolution of views : 0.21318367346938774
# average evolution of likes : 0.1333174603174603
# average evolution of dislikes : 0.17180498866213154

# %%
FalsePos = ErrorDf.loc[ErrorDf.prediction == 0.0]
FalsePos
# Out:
#        views_evo  likes_evo  dislikes_evo  comments_evo  prediction  trend  \
# 39731      0.037      0.025         0.042         0.020         0.0    1.0
# 39731      0.037      0.025         0.042         0.020         0.0    1.0
# 24105      0.082      0.039         0.069         0.021         0.0    1.0
# 7530       0.099      0.067         0.072         0.035         0.0    1.0
# 59698      0.059      0.008         0.048         0.021         0.0    1.0
# ...          ...        ...           ...           ...         ...    ...
# 41521      0.069      0.028         0.072         0.016         0.0    1.0
# 1719       0.058      0.022         0.027         0.019         0.0    1.0
# 60974      0.144      0.076         0.092         0.064         0.0    1.0
# 58505      0.006      0.002        -0.027         0.009         0.0    1.0
# 43455      0.095      0.053         0.076         0.042         0.0    1.0
#
#           video_id
# 39731          NaN
# 39731  8Mz95do8bD4
# ...

# %%
print("average evolution of comments :",FalsePos["comments_evo"].mean())
print("average evolution of views :",FalsePos["views_evo"].mean())
print("average evolution of likes :",FalsePos["likes_evo"].mean())
print("average evolution of dislikes :",FalsePos["dislikes_evo"].mean())
# Out:
# average evolution of comments : 0.05206884377758164
# average evolution of views : 0.07657281553398057
# average evolution of likes : 0.04944660194174757
# average evolution of dislikes : 0.06424183583406884

# %%
id_list = errorDetection['video_id'].to_list()
id_list = list(dict.fromkeys(id_list))

# %% [markdown]
# Confusion matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score

print("knn accuracy : ",accuracy_score(y_testn, pred))
print(confusion_matrix(y_testn, pred))
print(classification_report(y_testn, pred))
# Out:
# knn accuracy :  0.7637073756947574
# [[2964  441]
#  [1132 2120]]
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.87      0.79      3405
#          1.0       0.83      0.65      0.73      3252
#
#     accuracy                           0.76      6657
#    macro avg       0.78      0.76      0.76      6657
# weighted avg       0.77      0.76      0.76      6657

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(60, 30))
plot_tree(rfc1.estimators_[199], 
          feature_names=X.columns,
          class_names=str(rfc1.classes_), 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(0.5, 0.9, 'views_evo <= 0.185\ngini = 0.5\nsamples = 16854\nvalue = [13278, 13349]\nclass = 0'),
#  Text(0.25, 0.7, 'likes_evo <= 0.05\ngini = 0.441\nsamples = 11583\nvalue = [12269, 5999]\nclass = ['),
#  Text(0.125, 0.5, 'views_evo <= 0.041\ngini = 0.373\nsamples = 7773\nvalue = [9214, 3045]\nclass = ['),
#  Text(0.0625, 0.3, 'comments_evo <= 0.087\ngini = 0.328\nsamples = 3529\nvalue = [4438, 1158]\nclass = ['),
#  Text(0.03125, 0.1, 'gini = 0.324\nsamples = 3450\nvalue = [4365, 1113]\nclass = ['),
#  Text(0.09375, 0.1, 'gini = 0.472\nsamples = 79\nvalue = [73, 45]\nclass = ['),
#  Text(0.1875, 0.3, 'views_evo <= 0.146\ngini = 0.406\nsamples = 4244\nvalue = [4776, 1887]\nclass = ['),
#  Text(0.15625, 0.1, 'gini = 0.404\nsamples = 4162\nvalue = [4705, 1833]\nclass = ['),
#  Text(0.21875, 0.1, 'gini = 0.491\nsamples = 82\nvalue = [71, 54]\nclass = ['),
#  Text(0.375, 0.5, 'views_evo <= 0.142\ngini = 0.5\nsamples = 3810\nvalue = [3055, 2954]\nclass = ['),
# ...

# %% [markdown]
# DEEP LEARNING TEST

# %%
from keras.models import Sequential
from keras.layers import Dense
import keras
import numpy as np

# %%
import tensorflow_addons as tfa

def focal_loss_custom(alpha, gamma):   
    def binary_focal_loss(y_true, y_pred):      
        fl = tfa.losses.SigmoidFocalCrossEntropy(alpha=alpha, gamma=gamma)      
        y_true_K = K.ones_like(y_true)      
        focal_loss = fl(y_true, y_pred)      
        return focal_loss   
    return binary_focal_loss

# %%
import tensorflow as tf
tf.random.set_seed(42)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(lr=0.03),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

history = model.fit(X_trainn, y_trainn, epochs=30)
# Out:
# Epoch 1/30
# /usr/local/python/lib/python3.9/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 470/833 [===============>..............] - ETA: 0s - loss: 0.5242 - accuracy: 0.7307 - precision: 0.8182 - recall: 0.5999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9233/380117465.py in <module>
#      20 )
#      21
# ---> 22 history = model.fit(X_trainn, y_trainn, epochs=30)
#
# /usr/local/python/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
predictions = model.predict(X_testn)

# %%
prediction_classes = [
    1 if prob > 0.5 else 0 for prob in np.ravel(predictions)
]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_testn, prediction_classes))
# Out:
# [[2725  603]
#  [1132 2197]]

# %%
print(classification_report(y_testn, prediction_classes))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.82      0.76      3328
#          1.0       0.78      0.66      0.72      3329
#
#     accuracy                           0.74      6657
#    macro avg       0.75      0.74      0.74      6657
# weighted avg       0.75      0.74      0.74      6657
